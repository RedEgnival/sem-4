# %% [markdown]
# <a href="https://colab.research.google.com/github/RedEgnival/sem-4/blob/main/I069_ML_Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rusheel Sharma
# # I069
# # ML Lab 7 - KNN

# %% [markdown]
# # Task 1
# For the test data (1,1), determine the class using a)3-KNN, b) 5-KNN and c)7-KNN. Use below data set as training data set. Write your own user defined function for implementing KNN.

# %%
import numpy as np
import pandas as pd

# %%
xt = np.array([[-1,1],[0,1],[0,2],[1,-1],[1,0],[1,2],[2,2],[2,3]])
yt = np.array(["n","p","n","n","p","p","n","p"])
xtest = np.array([1,1])
# Out:
# Enter the value of k3

# %%
def knn1(xt,yt,xtest,k):
  dist = np.sqrt(np.sum((xt-xtest)**2, axis = 1))
  ni = np.argsort(dist)[:k]
  nc = yt[ni]
  uc,c = np.unique(nc,return_counts= True)
  return uc[np.argmax(c)]

# %%
k = int(input("Enter the value of k"))
pred = knn1(xt,yt,xtest,k)
print(pred)
# Out:
# Enter the value of k3
# p

# %%
k = int(input("Enter the value of k"))
pred = knn1(xt,yt,xtest,k)
print(pred)
# Out:
# Enter the value of k5
# p

# %%
k = int(input("Enter the value of k"))
pred = knn1(xt,yt,xtest,k)
print(pred)
# Out:
# Enter the value of k7
# n

# %% [markdown]
# # Task 2
# Implement kNN on the dataset test_knn.

# %%
d1 = pd.read_csv("/content/test_knn.csv")
d1
# Out:
#           a         b  c
# 0  2.781084  2.550537  0
# 1  1.465489  2.362125  0
# 2  3.396562  4.400294  0
# 3  1.388070  1.850220  0
# 4  3.064072  3.005306  0
# 5  7.627531  2.759262  1
# 6  5.332441  2.088627  1
# 7  6.922597  1.771064  1
# 8  8.675419 -0.242069  1
# 9  7.673756  3.508563  1

# %%
xtrain = d1.iloc[:,:-1].values
ytrain = d1.iloc[:,-1].values
xtest = np.array([1,1])

# %%
k = int(input("Enter the value of k"))
pred = knn1(xtrain,ytrain,xtest,k)
print(pred)
# Out:
# Enter the value of k3
# 0

# %%
k = int(input("Enter the value of k"))
pred = knn1(xtrain,ytrain,xtest,k)
print(pred)
# Out:
# Enter the value of k5
# 0

# %%
k = int(input("Enter the value of k"))
pred = knn1(xtrain,ytrain,xtest,k)
print(pred)
# Out:
# Enter the value of k7
# 0

# %% [markdown]
# # Task 3:
# For the given Social_Network_Ads.csv dataset. Perform below operations
# 1.	Upload the data set and store it in Pandas data frame
# 2.	Explore the dataset using head, describe and size commands
# 3.	Identify the input features and output feature
# 4.	Identify the total number of classes in output feature
# 5.	Remove columns that are not useful in classification
# 6.	Convert categorical column into numeric column
# 7.	Apply scalar transformation.

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("/content/Lab-7-Social_Network_Ads.csv")
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
df.size
# Out:
# 2000

# %%
lbe = LabelEncoder()
df["Gender"] = lbe.fit_transform(df["Gender"])
df["Gender"] #Male = 1
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 395    0
# 396    1
# 397    0
# 398    1
# 399    0
# Name: Gender, Length: 400, dtype: int64

# %%
x = df[["Age", "Gender", "EstimatedSalary"]].values
y = df["Purchased"]

# %% [markdown]
# # Task 4:
# Implement KNN algorithm on the given data set from Sklearn library with k=5.
# 1.	Split the data set into train and test
# 2.	Fit KNN model on train data set
# 3.	Identify class for the test data set
# 4.	Print confusion matrix
# 5.	Print accuracy score
# 6.	Write your inference

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(
             x, y, test_size = 0.2, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(data, classes)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
acc = accuracy_score(y_test,y_pred)
print(acc)
con = confusion_matrix(y_test,y_pred)
print(con)
# Out:
# 0.775
# [[49  3]
#  [15 13]]

# %% [markdown]
# # Task 5:
# 1.	Train KNN using different values of k.
# 2.	Determine the best value of k for the given dataset.

# %%
neighbors = np.arange(1, 9)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

# Loop over K values
for i, k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)

    # Compute training and test data accuracy
    train_accuracy[i] = knn.score(X_train, y_train)
    test_accuracy[i] = knn.score(X_test, y_test)


# Generate plot
plt.plot(neighbors, test_accuracy, label = 'Testing dataset Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training dataset Accuracy')

plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('Accuracy')
plt.show()

# %%
y_pred = knn.predict(X_test)
acc = accuracy_score(y_test,y_pred)
print(acc)
con = confusion_matrix(y_test,y_pred)
print(con)
# Out:
# 0.775
# [[49  3]
#  [15 13]]
