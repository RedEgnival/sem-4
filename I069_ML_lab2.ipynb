# %% [markdown]
# # Rusheel Sharma
# # I069
# # B.Tech AI
# # ML Lab 2

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
# i.	Read the Toyota.csv file into a DataFrame.
df=pd.read_csv("/content/lab-2-Toyota.csv")
df
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 10 columns]

# %%
# ii.	Explore size, shape, data types of each column in the dataset.
df.size
# Out:
# 14360

# %%
df.shape
# Out:
# (1436, 10)

# %%
df.dtypes
# Out:
# Price          int64
# Age          float64
# KM            object
# FuelType      object
# HP            object
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors         object
# Weight         int64
# dtype: object

# %%
# iii.	List down the columns of dataset
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
# iv.	Find out ‘Fuel Type’ for the 4th row.
df.loc[3,"FuelType"]
# Out:
# 'Diesel'

# %%
# v.	Find out value for second column for the 4th row.
df.iloc[3,1]
# Out:
# 26.0

# %%
# vi.	Select all rows for column “Fuel Type”
df["FuelType"]
# Out:
# 0       Diesel
# 1       Diesel
# 2       Diesel
# 3       Diesel
# 4       Diesel
#          ...
# 1431    Petrol
# 1432    Petrol
# 1433    Petrol
# 1434       NaN
# 1435    Petrol
# Name: FuelType, Length: 1436, dtype: object

# %%
# vii.	Select all rows for columns “KM”, “HP” and “Automatic”
df.loc[["KM","HP","Automatic"]]
# Out:
#          KM   HP  Automatic
# 0     46986   90          0
# 1     72937   90          0
# 2     41711   90          0
# 3     48000   90          0
# 4     38500   90          0
# ...     ...  ...        ...
# 1431  20544   86          0
# 1432     ??   86          0
# 1433  17016   86          0
# 1434     ??   86          0
# 1435      1  110          0
#
# [1436 rows x 3 columns]

# %%
# viii.	Display 1 to 5 rows for columns 2 to 4 (excluding row 5 and column 4)
df.iloc[1:5,2:4]
# Out:
#       KM FuelType
# 1  72937   Diesel
# 2  41711   Diesel
# 3  48000   Diesel
# 4  38500   Diesel

# %%
# ix.	Display the info of dataset and state your observations
df.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1436 non-null   object
#  3   FuelType   1336 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 112.3+ KB

# %%
# x.	Identify unique values for columns “KM”, “HP” and “Doors”
df[["KM","HP","Doors"]].nunique()
# Out:
# KM       1256
# HP         13
# Doors       7
# dtype: int64

# %%
# xi.	Create a new data frame, by replacing “??” with NAN
df.replace("??",np.nan,inplace=True)
df
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0    NaN   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0    NaN      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 10 columns]

# %%
# xii.	Replace the categorical values in the “Doors” column with its corresponding numeric value
df["Doors"].replace({"three":3,"four":4,"five":5},inplace=True)
df
# Out:
# <ipython-input-25-b5c9e78125b0>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Doors"].replace({"three":3,"four":4,"five":5},inplace=True)
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000     3
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000     3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000     3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000     3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000     3
# ...     ...   ...    ...      ...  ...       ...        ...   ...   ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300     3
# 1432  10845  72.0    NaN   Petrol   86       0.0          0  1300     3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300     3
# 1434   7250  70.0    NaN      NaN   86       1.0          0  1300     3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600     5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 10 columns]

# %%
# xiii.	Convert data types of columns “Doors”, “MetColor” and “Automatic” to int, and object
df["Doors"]=df["Doors"].astype(int)
df["MetColor"]=df["MetColor"].astype(object)
df["Automatic"]=df["Automatic"].astype(object)
df.dtypes
# Out:
# Price          int64
# Age          float64
# KM            object
# FuelType      object
# HP            object
# MetColor      object
# Automatic     object
# CC             int64
# Doors          int64
# Weight         int64
# dtype: object

# %%
# xiv.	Identify the total number of null values in each column of the data set
df.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             0
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
# xv.	Drop rows with null values
df.dropna(inplace=True)
df
# Out:
#       Price   Age     KM FuelType   HP MetColor Automatic    CC  Doors  Weight
# 0     13500  23.0  46986   Diesel   90      1.0         0  2000      3    1165
# 1     13750  23.0  72937   Diesel   90      1.0         0  2000      3    1165
# 3     14950  26.0  48000   Diesel   90      0.0         0  2000      3    1165
# 4     13750  30.0  38500   Diesel   90      0.0         0  2000      3    1170
# 5     12950  32.0  61000   Diesel   90      0.0         0  2000      3    1170
# ...     ...   ...    ...      ...  ...      ...       ...   ...    ...     ...
# 1423   7950  80.0  35821   Petrol   86      0.0         1  1300      3    1015
# 1424   7750  73.0  34717   Petrol   86      0.0         0  1300      3    1015
# 1429   8950  78.0  24000   Petrol   86      1.0         1  1300      5    1065
# 1430   8450  80.0  23000   Petrol   86      0.0         0  1300      3    1015
# 1435   6950  76.0      1   Petrol  110      0.0         0  1600      5    1114
#
# [1099 rows x 10 columns]

# %%
# xvi.	Identify total number of cars that runs on “Petrol”, “Diesel” or “CNG”
df["FuelType"].value_counts()
# Out:
# FuelType
# Petrol    970
# Diesel    117
# CNG        12
# Name: count, dtype: int64

# %%
# xvii.	Identify mean of “KM” for the cars that runs on “Diesel”
df['KM'] = pd.to_numeric(df['KM'], errors='coerce')
df[df["FuelType"]=="Diesel"].KM.mean()
# Out:
# 118123.06837606838

# %%
# Perform one hot and label encoding
label_encoder = preprocessing.LabelEncoder()
df['FuelType']= label_encoder.fit_transform(df['FuelType'])
df
# Out:
#       Price   Age     KM  FuelType   HP MetColor Automatic    CC  Doors  \
# 0     13500  23.0  46986         1   90      1.0         0  2000      3
# 1     13750  23.0  72937         1   90      1.0         0  2000      3
# 3     14950  26.0  48000         1   90      0.0         0  2000      3
# 4     13750  30.0  38500         1   90      0.0         0  2000      3
# 5     12950  32.0  61000         1   90      0.0         0  2000      3
# ...     ...   ...    ...       ...  ...      ...       ...   ...    ...
# 1423   7950  80.0  35821         2   86      0.0         1  1300      3
# 1424   7750  73.0  34717         2   86      0.0         0  1300      3
# 1429   8950  78.0  24000         2   86      1.0         1  1300      5
# 1430   8450  80.0  23000         2   86      0.0         0  1300      3
# 1435   6950  76.0      1         2  110      0.0         0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 3       1165
# 4       1170
# 5       1170
# ...      ...
# 1423    1015
# 1424    1015
# 1429    1065
# 1430    1015
# 1435    1114
#
# [1099 rows x 10 columns]

# %%
one_hot_encoded_data=pd.get_dummies(df,columns=['FuelType'])
one_hot_encoded_data
# Out:
#       Price   Age     KM   HP MetColor Automatic    CC  Doors  Weight  \
# 0     13500  23.0  46986   90      1.0         0  2000      3    1165
# 1     13750  23.0  72937   90      1.0         0  2000      3    1165
# 3     14950  26.0  48000   90      0.0         0  2000      3    1165
# 4     13750  30.0  38500   90      0.0         0  2000      3    1170
# 5     12950  32.0  61000   90      0.0         0  2000      3    1170
# ...     ...   ...    ...  ...      ...       ...   ...    ...     ...
# 1423   7950  80.0  35821   86      0.0         1  1300      3    1015
# 1424   7750  73.0  34717   86      0.0         0  1300      3    1015
# 1429   8950  78.0  24000   86      1.0         1  1300      5    1065
# 1430   8450  80.0  23000   86      0.0         0  1300      3    1015
# 1435   6950  76.0      1  110      0.0         0  1600      5    1114
#
#       FuelType_0  FuelType_1  FuelType_2
# 0          False        True       False
# 1          False        True       False
# 3          False        True       False
# 4          False        True       False
# 5          False        True       False
# ...          ...         ...         ...
# 1423       False       False        True
# 1424       False       False        True
# 1429       False       False        True
# 1430       False       False        True
# 1435       False       False        True
#
# [1099 rows x 12 columns]
